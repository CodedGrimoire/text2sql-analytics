# %% [markdown]
# {
#  "cells": [
#   {
#    "cell_type": "markdown",
#    "metadata": {},
#    "source": [
#     "# Text2SQL Analytics - Evaluation Notebook\n",
#     "This notebook helps analyze the query evaluation metrics and database schema."
#    ]
#   },
#   {
#    "cell_type": "code",
#    "execution_count": null,
#    "metadata": {},
#    "outputs": [],
#    "source": [
#     "import pandas as pd\n",
#     "import json\n",
#     "\n",
#     "# Load evaluation report\n",
#     "with open(\"EVALUATION.md\", \"r\") as f:\n",
#     "    eval_text = f.read()\n",
#     "\n",
#     "print(eval_text[:500])  # preview\n",
#     "\n",
#     "# Load dynamic report if exists\n",
#     "report = json.load(open(\"data/outputs/dynamic_report.json\"))\n",
#     "pd.DataFrame(report['metrics']).T.head()"
#    ]
#   },
#   {
#    "cell_type": "code",
#    "execution_count": null,
#    "metadata": {},
#    "outputs": [],
#    "source": [
#     "# Plot null counts for tables\n",
#     "import matplotlib.pyplot as plt\n",
#     "\n",
#     "metrics = report['metrics']\n",
#     "for table, m in metrics.items():\n",
#     "    nulls = m['null_counts']\n",
#     "    pd.Series(nulls).plot(kind='bar', title=f\"Null counts in {table}\")\n",
#     "    plt.show()"
#    ]
#   }
#  ],
#  "metadata": {
#   "kernelspec": {
#    "display_name": "Python 3",
#    "language": "python",
#    "name": "python3"
#   },
#   "language_info": {
#    "name": "python",
#    "version": "3.13"
#   }
#  },
#  "nbformat": 4,
#  "nbformat_minor": 5
# }
